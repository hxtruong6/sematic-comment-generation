# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv('../results/result_df.csv')

# %%
df.tail()
# Out:
#       hotel    hotel_name           created_at  num_topics  num_words  \
# 4495   -1.0  GLOBAL_TOPIC  2022/09/30 20:47:41        57.0       95.0
# 4496   -1.0  GLOBAL_TOPIC  2022/09/30 20:47:41        57.0       96.0
# 4497   -1.0  GLOBAL_TOPIC  2022/09/30 20:47:41        57.0       97.0
# 4498   -1.0  GLOBAL_TOPIC  2022/09/30 20:47:41        57.0       98.0
# 4499   -1.0  GLOBAL_TOPIC  2022/09/30 20:47:41        57.0       99.0
#
#       epoches                                             topics  perplexity  \
# 4495     20.0  (0, '0.037*"hotel" + 0.027*"breakfast" + 0.022...    -6.88075
# 4496     20.0  (0, '0.037*"hotel" + 0.027*"breakfast" + 0.022...    -6.88075
# 4497     20.0  (0, '0.037*"hotel" + 0.027*"breakfast" + 0.022...    -6.88075
# 4498     20.0  (0, '0.037*"hotel" + 0.027*"breakfast" + 0.022...    -6.88075
# 4499     20.0  (0, '0.037*"hotel" + 0.027*"breakfast" + 0.022...    -6.88075
#
#       coherence_score
# 4495         0.371883
# 4496         0.371883
# ...

# %%
sns.lineplot(x = "num_topics", y = "perplexity", data=df)
plt.show()

# %%
sns.lineplot(x = "num_topics", y = "coherence_score", data=df)
plt.show()
